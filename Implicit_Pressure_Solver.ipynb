# %%
from pprint import pprint
import numpy as np
import scipy as sp
import math
from matplotlib import pyplot as plt
from pylab import rcParams
from mpl_toolkits.mplot3d.axes3d import Axes3D
rcParams['font.size'] = 16
rcParams['figure.figsize'] = (20,16)
#from Jacobi_Solver import Jacobi_Solver
#from SOR_Solver import SOR
#from Conjugate_Gradient_Solver import Conj_Grad

# %% [markdown]
# # Iterative Solvers

# %%
def Jacobi_Solver(A,b,max_iter,sigma):
    """Uses the jacobi method to solve Ax=b
    
    Params:
    ------
    A         square coefficient matrix n by m
    b         RHS of matrix n by 1
    max_iter  maximum number of iterations before breaking
    sigma     desired convergence level
    
    Returns:
    ------
    x       solved variable matrix
    """
    
    #create intial guess x the size of A's first column
    x0 = np.zeros((A.shape[0],1), dtype=float) 
    x1 = np.empty((A.shape[0],1), dtype=float)
    I = np.eye(A.shape[0])
    D = np.diag(A)
    q = np.dot(np.diagflat(1/D),b)
    k = 0
    error = 100.0
    
    while abs(error) > sigma:
        if k > max_iter:
            print("Maximum number of iterations reached for Jacobi")
            break
        else:
            x1 = np.dot((I - np.dot(np.diagflat(1/D),A)),x0) + q
            diff = x1 - x0
            error = np.linalg.norm(diff, ord=2) 
            x0 = x1.copy()
            k += 1
    
    bnorm = np.linalg.norm(b,ord=2)
    total_error = np.linalg.norm(diff,ord=2) / bnorm
    
    return x1, total_error

# %%
def SOR(A,b,omega,max_iter,sigma):
    """Solves Ax=b using the successive over relaxation method, if omega=1
    this methods becomes Gauss-Seidel
    
    Params:
    ------
    A         square coefficient matrix n by m
    b         RHS of matrix n by 1
    omega     relaxation parameter
    max_iter  maximum number of iterations before breaking
    sigma     desired convergence level
    
    Returns:
    ------
    x       solved variable matrix
    """
    #generating first guess matrix
    x0 = np.zeros((A.shape[0],1), dtype=float) 
    x1 = np.empty((A.shape[0],1), dtype=float)
    I = np.eye(A.shape[0],dtype=float)
    L = np.tril(A,-1)
    U = np.triu(A,1)
    D = np.diag(A)
    temp = np.linalg.inv(L + np.diagflat(D))
    q = np.dot(temp,b)
    k = 0
    error = 100.0
    
    while abs(error) > sigma:
        if k > max_iter:
            print("Maximum number of iterations reached for SOR")
            break
        else:
            x1 = np.dot((omega*(I - np.dot(temp,A))) + ((1-omega)*I),x0) + omega*q
            diff = x1 - x0
            error = np.linalg.norm(diff, ord=2) 
            x0 = x1.copy()
            k += 1
            
    bnorm = np.linalg.norm(b,ord=2)
    total_error = np.linalg.norm(diff,ord=2) / bnorm
    return x1, total_error

# %%
def Conj_Grad(A,b,max_iter):
    """Solves Ax=b using the conjugate gradient method
    
    Params:
    ------
    A         Positive Definite and symmetric coefficient matrix m by m
    b         RHS of matrix m by 1
    max_iter  maximum number of iterations before breaking
    
    Returns:
    ------
    x   
    """
    x = np.zeros((A.shape[0],1), dtype=float)
    r = b.copy()
    rtr = np.dot(r.T,r)
    d = r.copy()
    k = 0
    error = 100
    
    while abs(error) > 1e-4:
        if  k > max_iter:
            print("Maximum number of iterations reached for Conjugate Gradient")
            break
        else:
            Ad = np.dot(A,d)
            alpha = rtr / np.dot(d.T,Ad)
            x = x + alpha * d
            r = r - alpha * Ad
            rtrold = rtr
            rtr = np.dot(r.T,r)
            beta = rtr / rtrold
            d = r + beta * d

            error = np.sqrt(rtr)/np.linalg.norm(b, ord=2)
            k +=k

    bnorm = np.linalg.norm(b,ord=2)
    total_error = np.linalg.norm(r,ord=2) / bnorm
    return x, total_error

# %%
def Poisson_Solver_Dirichlet(x_s,x_e,y_s,y_e,N_x,N_y,nwavex,nwavey):
    """Solves the 2D Poisson equation implicitly on a staggered grid using Dirichlet Boundary Conditions
    
    Params:
    ------
    x_s, x_e       float, Starting and ending points of x
    y_s, y_e       float, Starting and ending points of y
    N_x, N_y       float, Number of segments in x and y
    nwavex, nwavey float, wave number in x and y
    
    Returns:
    -------
    ADir         2D array of float, A matrix with Dirichlet conditions
    f_RHSd       1D array of float, f(x,y) for Dirichlet conditions
    N_cx, N_cy   float, number of cell centered points in x and y
    X, Y         2D array of float, meshgrid of x and y
    combod       2D array of float, the exact solution of the Poisson equation with Dirichlet conditions
    """
    #Grid Building
    L_x, L_y = x_e - x_s, y_e - y_s #length of domain
    N_GC = 1 #thickness of ghost cell boundary

    N_fx = N_x + 1 #number of face cells in x
    N_cx = N_x     #number of center cells in x
    N_fy = N_y + 1 #number of face cells in y
    N_cy = N_y     #number of center cells in y

    xf = np.zeros((N_fx,1),dtype=float) #initialize x face points
    dxc = np.zeros((N_cx,1),dtype=float) #initializing x center delta points
    xc = np.zeros_like(dxc,dtype=float) #intializing x center points

    yf = np.zeros((N_fy,1),dtype=float)
    dyc = np.zeros((N_cy,1),dtype=float)
    yc = np.zeros_like(dyc,dtype=float) 

    #x grid
    for i in range(0,N_fx):
        xf[i] = x_s + (i*(L_x/N_x))

    for i in range(0,N_cx):
        dxc[i] = xf[i+1] - xf[i] #delta x for face centers
        xc[i] = xf[i] + 0.5*dxc[i]

    dx1 = dxc.copy() #setting face and center dx values equal
    dx = np.insert(dx1,0,dx1[0]) #or append

    #y grid
    for j in range(0,N_fy):
        yf[j] = y_s + (j*(L_y/N_y))

    for j in range(0,N_cy):
        dyc[j] = yf[j+1] - yf[j] #delta y for centers
        yc[j] = yf[j] + 0.5*dyc[j]

    dy1 = dyc.copy() #setting face and center dy values equal
    dy = np.insert(dy1,0,dy1[0])

    #Ghost cells
    N_cxGC = N_cx + 2.0*N_GC
    N_cyGC = N_cy + 2.0*N_GC

    top = N_GC + 1
    bottom = N_GC + N_cx
    left = N_GC + 1
    right = N_GC + N_cy

    [X,Y] = np.meshgrid(xc,yc)
    
    ADir = np.zeros((N_cx*N_cy,N_cx*N_cy),dtype=float)

    #Building A
    a = N_cx * N_cy
    b = N_cx * N_cy
    c = -4 * (N_cx * N_cy)
    d = N_cx * N_cy
    e = N_cx * N_cy

    #Set corner points
    ADir[0,0] = c
    ADir[-1,-1] = c
    ADir[-1*N_cy,-1*N_cx] = c
    ADir[N_cx-1,N_cy-1] = c

    #Set edges in first block
    for j in range(1,N_cy-1):
        ADir[j,j] = c
        j +=j

    #Set edges in last block
    for j in range((N_cx*N_cy)-N_cy,(N_cx*N_cy)-2):
        ADir[j+1,j+1] = c
        j +=j

    #Set edges along main diagonal except for first block
    for j in range(N_cx+1,N_cy*N_cx):
        if j % N_cx ==0:
            #ADir[j,j] = c_edge
            ADir[j-1,j-1] = c
        j +=j

    #Set edges on main diagonal except for last block
    for j in range(N_cx,(N_cy*N_cx)-N_cx):
        if j % N_cx ==0:
            ADir[j,j] = c
            #ANeum[j-1,j-1] = c_edge
        j +=j

    #Second diagonal above and below diagonal
    for j in range(N_cy,N_cy*N_cx):
        ADir[j,j-N_cy] = a
        ADir[j-N_cx,j] = e
        j +=j

    #first diagonal below main diagonal   
    for j in range(1,N_cy*N_cx):
        if j % N_cy ==0:
            ADir[j,j-1] = 0
        else:
            ADir[j,j-1] = b
        j +=j

    #first diagonal above main diagonal
    for j in range(0,N_cy*N_cx):
        if j % N_cx ==0:
            ADir[j-1,j] = 0
        else:
            ADir[j-1,j] = d
        j +=j

    #Main Diagonal
    for j in range(0,N_cy*N_cx):
        if ADir[j,j] ==0:
            ADir[j,j] = c

    #Building f(x,y)
    combod = np.zeros((N_cx,N_cy),dtype=float)
    fd = np.zeros_like(combod,dtype=float)
    for j in range(0,N_x):
        y_exactd = np.sin(2.0*math.pi*nwavey*yc[j])
        for i in range(0,N_y):
            #ii = N_x*(j-1) + i
            x_exactd = np.sin(2.0*math.pi*nwavex*xc[i])
            combod[j,i] =  x_exactd * y_exactd
            fd[j,i] = -((2.0*nwavex*math.pi)**2 + ((2.0*nwavey*math.pi)\
                **2)) * y_exactd * x_exactd
    
    #building RHS dirichlet
    f_RHSd = np.zeros((N_cx*N_cy,1),dtype=float)
    for j in range(0,N_cy):
        for i in range(0,N_cx):
            ii = N_cx*(j) + i #original had j-1 if do this w/ N_cy/N_cx -1 CG gets slightly better still bad
            f_RHSd[ii,0] = fd[j,i]
    
    return ADir, f_RHSd, N_cx, N_cy, X, Y, combod

# %%
def Poisson_Solver_Neumann(x_s,x_e,y_s,y_e,N_x,N_y,nwavex,nwavey):
    """Solves the 2D Poisson equation implicitly on a staggered grid using Dirichlet Boundary Conditions
    
    Params:
    ------
    x_s, x_e       float, Starting and ending points of x
    y_s, y_e       float, Starting and ending points of y
    N_x, N_y       float, Number of segments in x and y
    nwavex, nwavey float, wave number in x and y
    
    Returns:
    -------
    ANeum        2D array of float, A matrix with Neumann conditions
    f_RHSn       1D array of float, f(x,y) for Neumann conditions
    N_cx, N_cy   float, number of cell centered points in x and y
    X, Y         2D array of float, meshgrid of x and y
    combon       2D array of float, the exact solution of the Poisson equation with Neumann conditions
    
    """
    #Grid Building
    L_x, L_y = x_e - x_s, y_e - y_s #length of domain
    N_GC = 1 #thickness of ghost cell boundary

    N_fx = N_x + 1 #number of face cells in x
    N_cx = N_x     #number of center cells in x
    N_fy = N_y + 1 #number of face cells in y
    N_cy = N_y     #number of center cells in y

    xf = np.zeros((N_fx,1),dtype=float) #initialize x face points
    dxc = np.zeros((N_cx,1),dtype=float) #initializing x center delta points
    xc = np.zeros_like(dxc,dtype=float) #intializing x center points

    yf = np.zeros((N_fy,1),dtype=float)
    dyc = np.zeros((N_cy,1),dtype=float)
    yc = np.zeros_like(dyc,dtype=float) 

    #x grid
    for i in range(0,N_fx):
        xf[i] = x_s + (i*(L_x/N_x))

    for i in range(0,N_cx):
        dxc[i] = xf[i+1] - xf[i] #delta x for face centers
        xc[i] = xf[i] + 0.5*dxc[i]

    dx1 = dxc.copy() #setting face and center dx values equal
    dx = np.insert(dx1,0,dx1[0]) #or append

    #y grid
    for j in range(0,N_fy):
        yf[j] = y_s + (j*(L_y/N_y))

    for j in range(0,N_cy):
        dyc[j] = yf[j+1] - yf[j] #delta y for centers
        yc[j] = yf[j] + 0.5*dyc[j]

    dy1 = dyc.copy() #setting face and center dy values equal
    dy = np.insert(dy1,0,dy1[0])

    #Ghost cells
    N_cxGC = N_cx + 2.0*N_GC
    N_cyGC = N_cy + 2.0*N_GC

    top = N_GC + 1
    bottom = N_GC + N_cx
    left = N_GC + 1
    right = N_GC + N_cy

    [X,Y] = np.meshgrid(xc,yc)
    
    #Building A
    ANeum = np.zeros((N_cx*N_cy,N_cx*N_cy),dtype=float)

    a = N_cx * N_cy
    b = N_cx * N_cy
    c_int = -4 * (N_cx * N_cy)
    c_edge = -3 * (N_cx * N_cy)
    c_corner = -2 * (N_cx * N_cy)
    d = N_cx * N_cy
    e = N_cx * N_cy

    #Set corner points
    ANeum[0,0] = c_corner
    ANeum[-1,-1] = c_corner
    ANeum[-1*N_cy,-1*N_cx] = c_corner
    ANeum[N_cx-1,N_cy-1] = c_corner

    #Set edges in first block
    for j in range(1,N_cy-1):
        ANeum[j,j] = c_edge
        j +=j

    #Set edges in last block
    for j in range((N_cx*N_cy)-N_cy,(N_cx*N_cy)-2):
        ANeum[j+1,j+1] = c_edge
        j +=j

    #Set edges along main diagonal except for first block
    for j in range(N_cx+1,N_cy*N_cx):
        if j % N_cx ==0:
            #ANeum[j,j] = c_edge
            ANeum[j-1,j-1] = c_edge
        j +=j

    #Set edges on main diagonal except for last block
    for j in range(N_cx,(N_cy*N_cx)-N_cx):
        if j % N_cx ==0:
            ANeum[j,j] = c_edge
            #ANeum[j-1,j-1] = c_edge
        j +=j

    #Second diagonal above and below diagonal
    for j in range(N_cy,N_cy*N_cx):
        ANeum[j,j-N_cy] = a
        ANeum[j-N_cx,j] = e
        j +=j

    #first diagonal below main diagonal   
    for j in range(1,N_cy*N_cx):
        if j % N_cy ==0:
            ANeum[j,j-1] = 0
        else:
            ANeum[j,j-1] = b
        j +=j

    #first diagonal above main diagonal
    for j in range(0,N_cy*N_cx):
        if j % N_cx ==0:
            ANeum[j-1,j] = 0
        else:
            ANeum[j-1,j] = d
        j +=j

    #Main Diagonal
    for j in range(0,N_cy*N_cx):
        if ANeum[j,j] ==0:
            ANeum[j,j] = c_int

    #Setting random edge to Dirichlet
    ANeum[0,:] = 0 
    ANeum[0,N_cx] = 1
    
    #Building f(x,y)
    combon = np.zeros((N_cx,N_cy),dtype=float)
    fn = np.zeros_like(combon,dtype=float)
    for j in range(0,N_x):
        y_exactn = np.cos(2.0*math.pi*nwavey*yc[j])
        for i in range(0,N_y):
            #ii = N_x*(j-1) + i
            x_exactn = np.cos(2.0*math.pi*nwavex*xc[i])
            combon[j,i] = x_exactn * y_exactn
            fn[j,i] = -((2.0*nwavex*math.pi)**2 + ((2.0*nwavey*math.pi)\
                **2)) * y_exactn * x_exactn
            
    #building RHS Neuman
    #f_RHSn = np.zeros((N_cx*N_cy,1),dtype=float)
    #for j in range(0,N_cy):
    #    for i in range(0,N_cx):
    #        ii = N_cx*(j) + i #original had j-1 if do this w/ N_cy/N_cx -1 CG gets slightly better still bad
    #        f_RHSn[ii,0] = fn[j,i]
    #        f_RHSn[] = combon[0,N_cx]
            
    #building RHS Neuman
    temp = np.zeros((N_cx,N_cy), dtype=float)
    #f_RHS = np.zeros(((Nx)*(Ny),1), dtype=float)
    for i in range(0,N_cx-1):
        for j in range(0,N_cy-1):
            temp[i,j] = fn[j,i]        
    temp[0,N_cx] = combon[0,N_cx]
    f_RHS = np.reshape(temp, (N_cx*N_cy,1))
            
    return ANeum, f_RHSn, N_cx, N_cy, X, Y, combon

# %%
Adir2, bdir2, N_cx_d2, N_cy_d2, Xd2, Yd2, combod2 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,10,10,1,1)
pprint(bdir2)
# Out:
# array([[ -7.53970685],
#        [-19.7392088 ],
#        [-24.3990039 ],
#        [-19.7392088 ],
#        [ -7.53970685],
#        [  7.53970685],
#        [ 19.7392088 ],
#        [ 24.3990039 ],
#        [ 19.7392088 ],
#        [  7.53970685],
#        [-19.7392088 ],
#        [-51.67791956],
#        [-63.87742151],
#        [-51.67791956],
#        [-19.7392088 ],
#        [ 19.7392088 ],
#        [ 51.67791956],
#        [ 63.87742151],
#        [ 51.67791956],
#        [ 19.7392088 ],
#        [-24.3990039 ],
#        [-63.87742151],
#        [-78.95683521],
#        [-63.87742151],
#        [-24.3990039 ],
#        [ 24.3990039 ],
#        [ 63.87742151],
#        [ 78.95683521],
#        [ 63.87742151],
#        [ 24.3990039 ],
#        [-19.7392088 ],
#        [-51.67791956],
#        [-63.87742151],
#        [-51.67791956],
#        [-19.7392088 ],
#        [ 19.7392088 ],
#        [ 51.67791956],
#        [ 63.87742151],
#        [ 51.67791956],
#        [ 19.7392088 ],
#        [ -7.53970685],
#        [-19.7392088 ],
#        [-24.3990039 ],
#        [-19.7392088 ],
#        [ -7.53970685],
#        [  7.53970685],
#        [ 19.7392088 ],
#        [ 24.3990039 ],
#        [ 19.7392088 ],
#        [  7.53970685],
#        [  7.53970685],
#        [ 19.7392088 ],
#        [ 24.3990039 ],
#        [ 19.7392088 ],
#        [  7.53970685],
#        [ -7.53970685],
#        [-19.7392088 ],
#        [-24.3990039 ],
#        [-19.7392088 ],
#        [ -7.53970685],
#        [ 19.7392088 ],
#        [ 51.67791956],
#        [ 63.87742151],
#        [ 51.67791956],
#        [ 19.7392088 ],
#        [-19.7392088 ],
#        [-51.67791956],
#        [-63.87742151],
#        [-51.67791956],
#        [-19.7392088 ],
#        [ 24.3990039 ],
#        [ 63.87742151],
#        [ 78.95683521],
#        [ 63.87742151],
#        [ 24.3990039 ],
#        [-24.3990039 ],
#        [-63.87742151],
#        [-78.95683521],
#        [-63.87742151],
#        [-24.3990039 ],
#        [ 19.7392088 ],
#        [ 51.67791956],
#        [ 63.87742151],
#        [ 51.67791956],
#        [ 19.7392088 ],
#        [-19.7392088 ],
#        [-51.67791956],
#        [-63.87742151],
#        [-51.67791956],
#        [-19.7392088 ],
#        [  7.53970685],
#        [ 19.7392088 ],
#        [ 24.3990039 ],
#        [ 19.7392088 ],
#        [  7.53970685],
#        [ -7.53970685],
#        [-19.7392088 ],
#        [-24.3990039 ],
#        [-19.7392088 ],
#        [ -7.53970685]])

# %%
Aneum = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,3,3,1,1)
pprint(Aneum)
# Out:
# (array([[-18.,   9.,   0.,   9.,   0.,   0.,   0.,   0.,   0.],
#        [  9., -27.,   9.,   0.,   9.,   0.,   0.,   0.,   0.],
#        [  0.,   9., -18.,   0.,   0.,   9.,   0.,   0.,   0.],
#        [  9.,   0.,   0., -27.,   9.,   0.,   9.,   0.,   0.],
#        [  0.,   9.,   0.,   9., -36.,   9.,   0.,   9.,   0.],
#        [  0.,   0.,   9.,   0.,   9., -27.,   0.,   0.,   9.],
#        [  0.,   0.,   0.,   9.,   0.,   0., -18.,   9.,   0.],
#        [  0.,   0.,   0.,   0.,   9.,   0.,   9., -27.,   9.],
#        [  0.,   0.,   0.,   0.,   0.,   9.,   0.,   9., -18.]]),
#  array([[-19.7392088 ],
#        [ 39.4784176 ],
#        [-19.7392088 ],
#        [ 39.4784176 ],
#        [-78.95683521],
#        [ 39.4784176 ],
#        [-19.7392088 ],
#        [ 39.4784176 ],
#        [-19.7392088 ]]),
#  3,
#  3,
#  array([[ 0.16666667,  0.5       ,  0.83333333],
#        [ 0.16666667,  0.5       ,  0.83333333],
#        [ 0.16666667,  0.5       ,  0.83333333]]),
#  array([[ 0.16666667,  0.16666667,  0.16666667],
#        [ 0.5       ,  0.5       ,  0.5       ],
#        [ 0.83333333,  0.83333333,  0.83333333]]),
#  array([[ 0.25, -0.5 ,  0.25],
#        [-0.5 ,  1.  , -0.5 ],
#        [ 0.25, -0.5 ,  0.25]]))

# %%
#Calling Solver
#Adir1, bdir1, N_cx_d1, N_cy_d1, Xd1, Yd1, combod1 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,10,10,1,1)
Aneum1, bneum1, N_cx_n1, N_cy_n1, Xn1, Yn1, combon1 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,10,10,1,1)
#Adir2, bdir2, N_cx_d2, N_cy_d2, Xd2, Yd2, combod2 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,20,20,1,1)
#Aneum2, bneum2, N_cx_n2, N_cy_n2, Xn2, Yn2, combon2 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,20,20,1,1)
#Adir3, bdir3, N_cx_d3, N_cy_d3, Xd3, Yd3, combod3 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,40,40,1,1)
#Aneum3, bneum3, N_cx_n3, N_cy_n3, Xn3, Yn3, combon3 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,40,40,1,1)

#Adir4, bdir4, N_cx_d4, N_cy_d4, Xd4, Yd4, combod4 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,20,20,2,2)
#Aneum4, bneum4, N_cx_n4, N_cy_n4, Xn4, Yn4, combon4 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,20,20,2,2)
#Adir5, bdir5, N_cx_d5, N_cy_d5, Xd5, Yd5, combod5 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,40,40,2,2)
#Aneum5, bneum5, N_cx_n5, N_cy_n5, Xn5, Yn5, combon5 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,40,40,2,2)

#inverting A and solving
#print('Dirichlet')
#print('1')
#x_JSd1, JS_errord1 = Jacobi_Solver(Adir1,bdir1,750,1e-6)
#x_SORd1, SOR_errord1 = SOR(Adir1,bdir1,1.5,750,1e-6)
#x_CGd1, CG_errord1 = Conj_Grad(Adir1,bdir1,750)
#print('2')
#x_JSd2, JS_errord2 = Jacobi_Solver(Adir2,bdir2,750,1e-6)
#x_SORd2, SOR_errord2 = SOR(Adir2,bdir2,1.8,750,1e-6)
#x_CGd2, CG_errord2 = Conj_Grad(Adir2,bdir2,750)
#print('3')
#x_JSd3, JS_errord3 = Jacobi_Solver(Adir3,bdir3,1000,1e-6)
#x_SORd3, SOR_errord3 = SOR(Adir3,bdir3,1.8, 1000,1e-6)
#x_CGd3, CG_errord3 = Conj_Grad(Adir3,bdir3,1000)
#print('4')
#x_JSd4, JS_errord4 = Jacobi_Solver(Adir4,bdir4,1000,1e-6)
#x_SORd4, SOR_errord4 = SOR(Adir4,bdir4,1.5, 1000,1e-6)
#x_CGd4, CG_errord4 = Conj_Grad(Adir4,bdir4,1000)
#print('5')
#x_JSd5, JS_errord5 = Jacobi_Solver(Adir5,bdir5,1000,1e-6)
#x_SORd5, SOR_errord5 = SOR(Adir5,bdir5,1.5, 1000,1e-6)
#x_CGd5, CG_errord5 = Conj_Grad(Adir5,bdir5,1000)

#print('Neumann')
#print('1')
#x_JSn1, JS_errorn1 = Jacobi_Solver(Aneum1,bneum1,750,1e-6)
#x_SORn1, SOR_errorn1 = SOR(Aneum1,bneum1,1.8,750,1e-6)
x_CGn1, CG_errorn1 = Conj_Grad(Aneum1,bneum1,750)
#print('2')
#x_JSn2, JS_errorn2 = Jacobi_Solver(Aneum2,bneum2,750,1e-6)
#x_SORn2, SOR_errorn2 = SOR(Aneum2,bneum2,1.2,750,1e-6)
#x_CGn2, CG_errorn2 = Conj_Grad(Aneum2,bneum2,750)
#print('3')
#x_JSn3, JS_errorn3 = Jacobi_Solver(Aneum3,bneum3,1000,1e-6)
#x_SORn3, SOR_errorn3 = SOR(Aneum3,bneum3,1.5, 1000,1e-6)
#x_CGn3, CG_errorn3 = Conj_Grad(Aneum3,bneum3,1000)
#print('4')
#x_JSn4, JS_errorn4 = Jacobi_Solver(Aneum4,bneum4,1000,1e-6)
#x_SORn4, SOR_errorn4 = SOR(Aneum4,bneum4,1.5, 1000,1e-6)
#x_CGn4, CG_errorn4 = Conj_Grad(Aneum4,bneum4,1000)
#print('5')
#x_JSn5, JS_errorn5 = Jacobi_Solver(Aneum5,bneum5,1000,1e-6)
#x_SORn5, SOR_errorn5 = SOR(Aneum5,bneum5,1.5, 1000,1e-6)
#x_CGn5, CG_errorn5 = Conj_Grad(Aneum5,bneum5,1000)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-ce734a9eec0c> in <module>()
#       1 #Calling Solver
#       2 #Adir1, bdir1, N_cx_d1, N_cy_d1, Xd1, Yd1, combod1 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,10,10,1,1)
# ----> 3 Aneum1, bneum1, N_cx_n1, N_cy_n1, Xn1, Yn1, combon1 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,10,10,1,1)
#       4 #Adir2, bdir2, N_cx_d2, N_cy_d2, Xd2, Yd2, combod2 = Poisson_Solver_Dirichlet(0.0,1.0,0.0,1.0,20,20,1,1)
#       5 #Aneum2, bneum2, N_cx_n2, N_cy_n2, Xn2, Yn2, combon2 = Poisson_Solver_Neumann(0.0,1.0,0.0,1.0,20,20,1,1)
#
# <ipython-input-22-abffc0d4dfe9> in Poisson_Solver_Neumann(x_s, x_e, y_s, y_e, N_x, N_y, nwavex, nwavey)
#     165         for j in range(0,N_cy-1):
#     166             temp[i,j] = fn[j,i]
# --> 167     temp[0,N_cx] = combon[0,N_cx]
#     168     f_RHS = np.reshape(temp, (N_cx*N_cy,1))
#     169
#
# IndexError: index 10 is out of bounds for axis 1 with size 10

# %%
def error_analysis(N_cx,N_cy,x_vals,exact_sol):
    """Computes L2 norm of calculated solution
    
    Params:
    ------
    N_cx, N_cy  Number of cell centered points
    x_vals      calculated x_values
    exact_sol   Analytical Solution
    
    Returns:
    -------
    num         Number of total points
    normdiff    L2 norm of calculated solution
    """
    num = N_cx * N_cy
    temp = np.reshape(x_vals, (N_cy,N_cx))
    diff = exact_sol - temp
    normdiff = np.linalg.norm(diff,ord=2)
    
    return num, normdiff

# %%
#Error analysis
#D_JS1, normdiff_JS1d = error_analysis(N_cx_d1,N_cy_d1,x_JSd1,combod1)
#D_JS2, normdiff_JS2d = error_analysis(N_cx_d2,N_cy_d2,x_JSd2,combod2)
#D_JS3, normdiff_JS3d = error_analysis(N_cx_d3,N_cy_d3,x_JSd3,combod3)
#D_JS4, normdiff_JS4d = error_analysis(N_cx_d4,N_cy_d4,x_JSd4,combod4)
#D_JS5, normdiff_JS5d = error_analysis(N_cx_d5,N_cy_d5,x_JSd5,combod5)
#N_JS1, normdiff_JS1n = error_analysis(N_cx_n1,N_cy_n1,x_JSn1,combod1)
#N_JS2, normdiff_JS2n = error_analysis(N_cx_n2,N_cy_n2,x_JSn2,combon2)
#N_JS3, normdiff_JS3n = error_analysis(N_cx_n3,N_cy_n3,x_JSn3,combon3)
#N_JS4, normdiff_JS4n = error_analysis(N_cx_n4,N_cy_n4,x_JSn4,combon4)
#N_JS5, normdiff_JS5n = error_analysis(N_cx_n5,N_cy_n5,x_JSn5,combon5)

#D_SOR1, normdiff_SOR1d = error_analysis(N_cx_d1,N_cy_d1,x_SORd1,combod1)
#D_SOR2, normdiff_SOR2d = error_analysis(N_cx_d2,N_cy_d2,x_SORd2,combod2)
#D_SOR3, normdiff_SOR3d = error_analysis(N_cx_d3,N_cy_d3,x_SORd3,combod3)
#D_SOR4, normdiff_SOR4d = error_analysis(N_cx_d4,N_cy_d4,x_SORd4,combod4)
#D_SOR5, normdiff_SOR5d = error_analysis(N_cx_d5,N_cy_d5,x_SORd5,combod5)
#N_SOR1, normdiff_SOR1n = error_analysis(N_cx_d1,N_cy_n1,x_SORn1,combon1)
#N_SOR2, normdiff_SOR2n = error_analysis(N_cx_n2,N_cy_n2,x_SORn2,combon2)
#N_SOR3, normdiff_SOR3n = error_analysis(N_cx_n3,N_cy_n3,x_SORn3,combon3)
#N_SOR4, normdiff_SOR4n = error_analysis(N_cx_n4,N_cy_n4,x_SORn4,combon4)
#N_SOR5, normdiff_SOR5n = error_analysis(N_cx_n5,N_cy_n5,x_SORn5,combon5)

#D_CG1, normdiff_CG1d = error_analysis(N_cx_d1,N_cy_d1,x_CGd1,combod1)
#D_CG2, normdiff_CG2d = error_analysis(N_cx_d2,N_cy_d2,x_CGd2,combod2)
#D_CG3, normdiff_CG3d = error_analysis(N_cx_d3,N_cy_d3,x_CGd3,combod3)
#D_CG4, normdiff_CG4d = error_analysis(N_cx_d4,N_cy_d4,x_CGd4,combod4)
#D_CG5, normdiff_CG5d = error_analysis(N_cx_d5,N_cy_d5,x_CGd5,combod5)
N_CG1, normdiff_CG1n = error_analysis(N_cx_n1,N_cy_n1,x_CGn1,combon1)
#N_CG2, normdiff_CG2n = error_analysis(N_cx_n2,N_cy_n2,x_CGn2,combon2)
#N_CG3, normdiff_CG3n = error_analysis(N_cx_n3,N_cy_n3,x_CGn3,combon3)
#N_CG4, normdiff_CG4n = error_analysis(N_cx_n4,N_cy_n4,x_CGn4,combon4)
#N_CG5, normdiff_CG5n = error_analysis(N_cx_n5,N_cy_n5,x_CGn5,combon5)

# %%
#wave number 1
stack_d_JS = np.vstack((D_JS1,D_JS2,D_JS3))
stack_d_JSnorm = np.vstack((normdiff_JS1d,normdiff_JS2d,normdiff_JS3d))
stack_d_SOR = np.vstack((D_SOR1,D_SOR2,D_SOR3))
stack_d_SORnorm = np.vstack((normdiff_SOR1d,normdiff_SOR2d,normdiff_SOR3d))
stack_d_CG = np.vstack((D_CG1,D_CG2,D_CG3))
stack_d_CGnorm = np.vstack((normdiff_CG1d,normdiff_CG2d,normdiff_CG3d))
stack_n_JS = np.vstack((N_JS1,N_JS2,N_JS3))
stack_n_JSnorm = np.vstack((normdiff_JS1n,normdiff_JS2n,normdiff_JS3n))
stack_n_SOR = np.vstack((N_SOR1,N_SOR2,N_SOR3))
stack_n_SORnorm = np.vstack((normdiff_SOR1n,normdiff_SOR2n,normdiff_SOR3n))
stack_n_CG = np.vstack((N_CG1,N_CG2,N_CG3))
stack_n_CGnorm = np.vstack((normdiff_CG1n,normdiff_CG2n,normdiff_CG3n))

#wave number 2
stack_d_JS2 = np.vstack((D_JS4,D_JS5))
stack_d_JSnorm2 = np.vstack((normdiff_JS4d,normdiff_JS5d))
stack_d_SOR2 = np.vstack((D_SOR4,D_SOR5))
stack_d_SORnorm2 = np.vstack((normdiff_SOR4d,normdiff_SOR5d))
stack_d_CG2 = np.vstack((D_CG4,D_CG5))
stack_d_CGnorm2 = np.vstack((normdiff_CG4d,normdiff_CG5d))
stack_n_JS2 = np.vstack((N_JS4,N_JS5))
stack_n_JSnorm2 = np.vstack((normdiff_JS4n,normdiff_JS5n))
stack_n_SOR2 = np.vstack((N_SOR4,N_SOR5))
stack_n_SORnorm2 = np.vstack((normdiff_SOR4n,normdiff_SOR5n))
stack_n_CG2 = np.vstack((N_CG4,N_CG5))
stack_n_CGnorm2 = np.vstack((normdiff_CG4n,normdiff_CG5n))

plt.figure(figsize=(10,10))
plt.title('Error Analysis of Dirichlet Boundary Condition Jacobi Scheme\nWave Number 1 is red, Wave Number 2 is blue')
plt.xlabel('Number of Iterations')
plt.ylabel('L2-norm of error')
plt.xlim([0,2000])
plt.plot(stack_d_JS,stack_d_JSnorm, 'ro--', stack_d_JS2,stack_d_JSnorm2, 'bo--');
plt.savefig('JS_D.png')

plt.figure(figsize=(10,10))
plt.title('Error Analysis of Dirichlet Boundary Condition SOR Scheme\nWave Number 1 is red, Wave Number 2 is blue')
plt.xlabel('Number of Iterations')
plt.ylabel('L2-norm of error')
plt.xlim([0,2000])
plt.plot(stack_d_SOR,stack_d_SORnorm, 'ro--', stack_d_SOR2,stack_d_SORnorm2, 'bo--');
plt.savefig('SOR_D.png')

plt.figure(figsize=(12,12))
plt.title('Error Analysis of Dirichlet Boundary Condition Conjugate Gradient Scheme\nWave Number 1 is red, Wave Number 2 is blue')
plt.xlabel('Number of Iterations')
plt.ylabel('L2-norm of error')
plt.xlim([0,2000])
plt.plot(stack_d_CG,stack_d_CGnorm, 'ro--', stack_d_CG2,stack_d_CGnorm2, 'bo--');
plt.savefig('CG_D.png')

plt.figure(figsize=(10,10))
plt.title('Error Analysis of Neumann Boundary Condition Jacobi Scheme\nWave Number 1 is red, Wave Number 2 is blue')
plt.xlabel('Number of Iterations')
plt.ylabel('L2-norm of error')
plt.xlim([0,2000])
plt.plot(stack_n_JS,stack_n_JSnorm, 'ro--', stack_n_JS2,stack_n_JSnorm2, 'bo--');
plt.savefig('JS_N.png')

plt.figure(figsize=(10,10))
plt.title('Error Analysis of Neumann Boundary Condition SOR Scheme\nWave Number 1 is red, Wave Number 2 is blue')
plt.xlabel('Number of Iterations')
plt.ylabel('L2-norm of error')
plt.xlim([0,2000])
plt.plot(stack_n_SOR,stack_n_SORnorm, 'ro--', stack_n_SOR2,stack_n_SORnorm2, 'bo--');
plt.savefig('SOR_N.png')

plt.figure(figsize=(12,12))
plt.title('Error Analysis of Neumann Boundary Condition Conjugate Gradient Scheme\nWave Number 1 is red, Wave Number 2 is blue')
plt.xlabel('Number of Iterations')
plt.ylabel('L2-norm of error')
plt.xlim([0,2000])
plt.plot(stack_n_CG,stack_n_CGnorm, 'ro--', stack_n_CG2,stack_n_CGnorm2, 'bo--');
plt.savefig('CG_N.png')

# %%
temp = np.reshape(x_CGn1, (N_cy_n1,N_cx_n1))

# %matplotlib inline
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1, 1, 1, projection='3d')
Gx, Gy = np.gradient(temp)
G = (Gx**2 + Gy**2)**.5
N = G/G.max()
p = ax.plot_surface(Xn1, Yn1, temp, rstride=1, cstride=1)#, \
    #facecolors=cm.jet(N),linewidth=0)
#plt.savefig('JS_N_40_2_num.png')

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1, 1, 1, projection='3d')
Gx, Gy = np.gradient(combon1)
G = (Gx**2 + Gy**2)**.5
N = G/G.max()
p = ax.plot_surface(Xn1, Yn1, combon1, rstride=1, cstride=1)#, \
    #facecolors=cm.jet(N), linewidth=0)
#plt.savefig('JS_N_40_2_exact.png')

diff = combon1 - temp

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1, 1, 1, projection='3d')
Gx, Gy = np.gradient(diff)
G = (Gx**2 + Gy**2)**.5
N = G/G.max()
p = ax.plot_surface(Xn1, Yn1, diff, rstride=1, cstride=1)#, \
    #facecolors=cm.jet(N),linewidth=0)

#plt.savefig('JS_N_40_2_error.png')

# %%
from IPython.core.display import HTML
css_file = 'numericalmoocstyle.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
